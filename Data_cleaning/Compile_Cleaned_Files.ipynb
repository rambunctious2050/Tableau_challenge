# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# # Concatenate PerDayStats Files For All Months

# %%
# Load all the PerDayStats data
file1 = "../Cleaned_Data/2019_Feb_PerDayStats.csv"
file2 = "../Cleaned_Data/2019_Mar_PerDayStats.csv"
file3 = "../Cleaned_Data/2019_Apr_PerDayStats.csv"

file4 = "../Cleaned_Data/2020_Feb_PerDayStats.csv"
file5 = "../Cleaned_Data/2020_Mar_PerDayStats.csv"
file6 = "../Cleaned_Data/2020_Apr_PerDayStats.csv"

# %%
# Read file and store into Pandas dataframe
f1 = pd.read_csv(file1)
f2 = pd.read_csv(file2)
f3 = pd.read_csv(file3)

f4 = pd.read_csv(file4)
f5 = pd.read_csv(file5)
f6 = pd.read_csv(file6)

# %%
# Convert all of them to dataframes
df1 = pd.DataFrame(f1)
df2 = pd.DataFrame(f2)
df3 = pd.DataFrame(f3)

df4 = pd.DataFrame(f4)
df5 = pd.DataFrame(f5)
df6 = pd.DataFrame(f6)

# %%
frames = [df1, df2, df3, df4, df5, df6]
PerDayStats_Total = pd.concat(frames)
PerDayStats_Total = PerDayStats_Total.round(0)

# %%
PerDayStats_Total
# Out:
#      Trip_Year  Trip_Month  Trip_Day  gender    usertype  trip_count  \
# 0         2019           2         1       1    Customer         314
# 1         2019           2         1       1  Subscriber       19378
# 2         2019           2         1       2    Customer          32
# 3         2019           2         1       2  Subscriber        4680
# 4         2019           2         2       1    Customer         528
# ..         ...         ...       ...     ...         ...         ...
# 115       2020           4        29       2  Subscriber        5261
# 116       2020           4        30       1    Customer         892
# 117       2020           4        30       1  Subscriber        8923
# 118       2020           4        30       2    Customer         454
# 119       2020           4        30       2  Subscriber        3246
#
#      avg_trip_length (min)
# 0                     20.0
# 1                     12.0
# 2                     33.0
# ...

# %% [markdown]
# # Concatenate PopularStartRoutes Files For All Months

# %%
# Load all the PopularStartRoutes data
files1 = "../Cleaned_Data/2019_Feb_PopularStartRoutes.csv"
files2 = "../Cleaned_Data/2019_Mar_PopularStartRoutes.csv"
files3 = "../Cleaned_Data/2019_Apr_PopularStartRoutes.csv"

files4 = "../Cleaned_Data/2020_Feb_PopularStartRoutes.csv"
files5 = "../Cleaned_Data/2020_Mar_PopularStartRoutes.csv"
files6 = "../Cleaned_Data/2020_Apr_PopularStartRoutes.csv"

# %%
# Read file and store into Pandas dataframe
fs1 = pd.read_csv(files1)
fs2 = pd.read_csv(files2)
fs3 = pd.read_csv(files3)

fs4 = pd.read_csv(files4)
fs5 = pd.read_csv(files5)
fs6 = pd.read_csv(files6)

# %%
# Convert all of them to dataframes
dfs1 = pd.DataFrame(fs1)
dfs2 = pd.DataFrame(fs2)
dfs3 = pd.DataFrame(fs3)

dfs4 = pd.DataFrame(fs4)
dfs5 = pd.DataFrame(fs5)
dfs6 = pd.DataFrame(fs6)

# %%
frames = [dfs1, dfs2, dfs3, dfs4, dfs5, dfs6]
PopularStartRoutes_Total = pd.concat(frames)
PopularStartRoutes_Total
# Out:
#      Trip_Year  Trip_Month            start station name  \
# 0         2019           2              1 Ave & E 110 St
# 1         2019           2               1 Ave & E 16 St
# 2         2019           2               1 Ave & E 18 St
# 3         2019           2               1 Ave & E 30 St
# 4         2019           2               1 Ave & E 44 St
# ..         ...         ...                           ...
# 910       2020           4      Woodward Ave & Harman St
# 911       2020           4     Wyckoff Av & Jefferson St
# 912       2020           4      Wyckoff Av & Stanhope St
# 913       2020           4        Wyckoff St & Nevins St
# 914       2020           4  Wythe Ave & Metropolitan Ave
#
#      start station latitude  start station longitude  trip_count
# 0                 40.792327               -73.938300        8084
# 1                 40.732219               -73.981656        8084
# 2                 40.733812               -73.980544        8084
# ...

# %% [markdown]
# # Concatenate PopularEndRoutes Files For All Months

# %%
# Load all the PopularEndRoutes data
filee1 = "../Cleaned_Data/2019_Feb_PopularEndRoutes.csv"
filee2 = "../Cleaned_Data/2019_Mar_PopularEndRoutes.csv"
filee3 = "../Cleaned_Data/2019_Apr_PopularEndRoutes.csv"

filee4 = "../Cleaned_Data/2020_Feb_PopularEndRoutes.csv"
filee5 = "../Cleaned_Data/2020_Mar_PopularEndRoutes.csv"
filee6 = "../Cleaned_Data/2020_Apr_PopularEndRoutes.csv"

# %%
# Read file and store into Pandas dataframe
fe1 = pd.read_csv(filee1)
fe2 = pd.read_csv(filee2)
fe3 = pd.read_csv(filee3)

fe4 = pd.read_csv(filee4)
fe5 = pd.read_csv(filee5)
fe6 = pd.read_csv(filee6)

# %%
# Convert all of them to dataframes
dfe1 = pd.DataFrame(fe1)
dfe2 = pd.DataFrame(fe2)
dfe3 = pd.DataFrame(fe3)

dfe4 = pd.DataFrame(fe4)
dfe5 = pd.DataFrame(fe5)
dfe6 = pd.DataFrame(fe6)

# %%
frames = [dfe1, dfe2, dfe3, dfe4, dfe5, dfe6]
PopularEndRoutes_Total = pd.concat(frames)
PopularEndRoutes_Total
# Out:
#      Trip_Year  Trip_Month              end station name  \
# 0         2019           2              1 Ave & E 110 St
# 1         2019           2               1 Ave & E 16 St
# 2         2019           2               1 Ave & E 18 St
# 3         2019           2               1 Ave & E 30 St
# 4         2019           2               1 Ave & E 44 St
# ..         ...         ...                           ...
# 914       2020           4      Woodward Ave & Harman St
# 915       2020           4     Wyckoff Av & Jefferson St
# 916       2020           4      Wyckoff Av & Stanhope St
# 917       2020           4        Wyckoff St & Nevins St
# 918       2020           4  Wythe Ave & Metropolitan Ave
#
#      end station latitude  end station longitude  trip_count
# 0               40.792327             -73.938300        8193
# 1               40.732219             -73.981656        8193
# 2               40.733812             -73.980544        8193
# ...

# %% [markdown]
# # Save the file in "Cleaned_Data"

# %%
PerDayStats_Total.to_csv(r'..\Final_Data\PerDayStats_Total.csv', index = False)
PopularStartRoutes_Total.to_csv(r'..\Final_Data\PopularStartRoutes_Total.csv', index = False)
PopularEndRoutes_Total.to_csv(r'..\Final_Data\PopularEndRoutes_Total.csv', index = False)
